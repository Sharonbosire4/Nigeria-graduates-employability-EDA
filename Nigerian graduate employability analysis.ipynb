# %% [markdown]
# # NIGERIA GRADUATE EMPLOYABILITY EXPLORATORY DATA ANALYSIS

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Import data
data = pd.read_csv("nigerian.csv")
(data)
# Out:
#                Timestamp What is your gender  Year of graduation  \
# 0       02/08/2018 09:05                Male                2013
# 1     2/15/2018 12:11:32                Male                2014
# 2     2/15/2018 13:47:10              Female                2013
# 3     2/16/2018 13:01:34                Male                2017
# 4     2/16/2018 13:18:03              Female                2013
# ...                  ...                 ...                 ...
# 5214  5/14/2018 19:51:56              Female                2014
# 5215  5/15/2018 10:17:12              Female                2017
# 5216  5/15/2018 10:33:45              Female                2014
# 5217  5/15/2018 13:49:47              Female                2015
# 5218  5/15/2018 23:39:09                Male                2016
#
#                                 Title of course studied  \
# 0                   Electrical & Electronic Engineering
# 1                                            Psychology
# ...

# %%
#column names
data.columns
# Out:
# Index(['Timestamp', 'What is your gender', 'Year of graduation',
#        'Title of course studied', 'Polytechnic/University attended',
#        'What is your highest level of education?',
#        'What best describes your current status?',
#        'How many jobs have you had since graduation including your current one?',
#        'Have you completed your NYSC?',
#        'If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?',
#        'Did you get your first full time job through your NYSC placement?',
#        'Thinking about your first employment after graduation, what was your job level?',
#        'What is/was your job role?',
#        'What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication)',
#        'Still thinking about your first employment, what is/was your monthly income level?',
# ...

# %%
data.head()
# Out:
#             Timestamp What is your gender  Year of graduation  \
# 0    02/08/2018 09:05                Male                2013
# 1  2/15/2018 12:11:32                Male                2014
# 2  2/15/2018 13:47:10              Female                2013
# 3  2/16/2018 13:01:34                Male                2017
# 4  2/16/2018 13:18:03              Female                2013
#
#                              Title of course studied  \
# 0                Electrical & Electronic Engineering
# 1                                         Psychology
# 2                                          Economics
# 3  Mass Communication (Communication and Language...
# 4                                         Statistics
#
#         Polytechnic/University attended  \
# 0    Obafemi Awolowo University,Ile-Ife
# 1    Obafemi Awolowo University,Ile-Ife
# 2  Bells University of Technology, Otta
# 3                 Bowen University, Iwo
# 4                Ekiti State University
#
# ...

# %%
data.tail()
# Out:
#                Timestamp What is your gender  Year of graduation  \
# 5214  5/14/2018 19:51:56              Female                2014
# 5215  5/15/2018 10:17:12              Female                2017
# 5216  5/15/2018 10:33:45              Female                2014
# 5217  5/15/2018 13:49:47              Female                2015
# 5218  5/15/2018 23:39:09                Male                2016
#
#       Title of course studied             Polytechnic/University attended  \
# 5214    Physics and Astronomy                         University of Lagos
# 5215         Acturial Science                         University of Lagos
# 5216        Political Science       Others (For foreign trained students)
# 5217  Business Administration  The Polytechnic Ibadan, Ibadab, Oyo State.
# 5218                Economics                Usumanu Danfodiyo University
#
#      What is your highest level of education?  \
# 5214                        Bachelor's degree
# ...

# %%
data.iloc[300:301,:]
# Out:
#               Timestamp What is your gender  Year of graduation  \
# 300  2/24/2018 13:34:09              Female                2017
#
#     Title of course studied     Polytechnic/University attended  \
# 300        Computer Science  Obafemi Awolowo University,Ile-Ife
#
#     What is your highest level of education?  \
# 300                        Bachelor's degree
#
#     What best describes your current status?  \
# 300      Working full time (paid employment)
#
#      How many jobs have you had since graduation including your current one?  \
# 300                                                  1
#
#     Have you completed your NYSC?  \
# 300                            No
#
#      If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?  \
# 300                                                NaN
#
#      ... What currency are you currently paid in?  \
# 300  ...                                    Naira
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5219 entries, 0 to 5218
# Data columns (total 36 columns):
# Timestamp                                                                                                                       5219 non-null object
# What is your gender                                                                                                             5219 non-null object
# Year of graduation                                                                                                              5219 non-null int64
# Title of course studied                                                                                                         5219 non-null object
# Polytechnic/University attended                                                                                                 5219 non-null object
# ...

# %%
data.drop('Thinking about your first employment after graduation, what was your job level?',axis=1,inplace=True)

# %%
data.drop('How many jobs have you had since graduation including your current one?',axis=1,inplace=True)

# %%
data.drop(['What currency are you currently paid in?','Approximately how many hours a day do you currently work?'],axis=1,inplace=True)

# %%
data.drop(['Were you able to rent an apartment or buy a car from the salary you got from your first job?','Thinking about your current employment, did you work for your employer before or during your  higher education study?','How do you find out about your job(s)?','Which sector is your most preferred sector to work in?'],axis=1,inplace=True)

# %%
data.drop(['Did you get your first full time job through your NYSC placement?','Reason why?','Which form of transport do you use the most?'],axis=1,inplace=True)

# %%
#checking datatype
data.dtypes
# Out:
# Timestamp                                                                                                                        object
# What is your gender                                                                                                              object
# Year of graduation                                                                                                                int64
# Title of course studied                                                                                                          object
# Polytechnic/University attended                                                                                                  object
# What is your highest level of education?                                                                                         object
# What best describes your current status?                                                                                         object
# ...

# %%
#Total number of rows and columns
data.shape
# Out:
# (5219, 25)

# %%
data
# Out:
#                Timestamp What is your gender  Year of graduation  \
# 0       02/08/2018 09:05                Male                2013
# 1     2/15/2018 12:11:32                Male                2014
# 2     2/15/2018 13:47:10              Female                2013
# 3     2/16/2018 13:01:34                Male                2017
# 4     2/16/2018 13:18:03              Female                2013
# 5     2/16/2018 16:44:18                Male                2015
# 6      2/19/2018 7:24:05                Male                2013
# 7      2/19/2018 8:40:37                Male                2015
# 8      2/19/2018 8:53:52              Female                2017
# 9      2/19/2018 8:57:02              Female                2015
# 10     2/19/2018 9:19:58                Male                2015
# 11    2/19/2018 10:31:10                Male                2016
# 12    2/19/2018 10:39:41                Male                2017
# ...

# %%
#Checking null values in the dataset
data.isnull().sum().any()
# Out:
# True

# %%
#Missing values
data.isnull().sum()
# Out:
# Timestamp                                                                                                                          0
# What is your gender                                                                                                                0
# Year of graduation                                                                                                                 0
# Title of course studied                                                                                                            0
# Polytechnic/University attended                                                                                                    0
# What is your highest level of education?                                                                                           0
# What best describes your current status?                                                                                           0
# ...

# %%
#Drop all the null values
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Timestamp                                                                                                                       0
# What is your gender                                                                                                             0
# Year of graduation                                                                                                              0
# Title of course studied                                                                                                         0
# Polytechnic/University attended                                                                                                 0
# What is your highest level of education?                                                                                        0
# What best describes your current status?                                                                                        0
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'What is your gender', 'Year of graduation',
#        'Title of course studied', 'Polytechnic/University attended',
#        'What is your highest level of education?',
#        'What best describes your current status?',
#        'Have you completed your NYSC?',
#        'If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?',
#        'What is/was your job role?',
#        'What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication)',
#        'Still thinking about your first employment, what is/was your monthly income level?',
#        'Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?',
#        'What was the most significant reason for deciding to take your first job?',
#        'Thinking about your current employment, what is your job level?',
#        'What is your job role?',
# ...

# %%
data.head()
# Out:
#              Timestamp What is your gender  Year of graduation  \
# 4   2/16/2018 13:18:03              Female                2013
# 5   2/16/2018 16:44:18                Male                2015
# 6    2/19/2018 7:24:05                Male                2013
# 8    2/19/2018 8:53:52              Female                2017
# 10   2/19/2018 9:19:58                Male                2015
#
#                           Title of course studied  \
# 4                                      Statistics
# 5             Electrical & Electronic Engineering
# 6                                       Economics
# 8   Industrial Relations and Personnel Management
# 10                                      Economics
#
#    Polytechnic/University attended What is your highest level of education?  \
# 4           Ekiti State University                        Bachelor's degree
# 5              University of Benin                        Bachelor's degree
# ...

# %%
#gender
sns.countplot(x='What is your gender',data=data)

# %%
#Number of people employed and year of graduation
gainfully_employed = data[(data['What best describes your current status?']=='Working full time (paid employment)') | (data['What best describes your current status?']=='Youth Corper (NYSC)') | (data['What best describes your current status?']=='Self-employed/freelance/entrepreneur')]

gainfully_employed.groupby(['Year of graduation', "What best describes your current status?"])['What best describes your current status?'].count()
# Out:
# Year of graduation  What best describes your current status?
# 2013                Self-employed/freelance/entrepreneur         32
#                     Working full time (paid employment)         153
#                     Youth Corper (NYSC)                           1
# 2014                Self-employed/freelance/entrepreneur         49
#                     Working full time (paid employment)         168
#                     Youth Corper (NYSC)                           1
# 2015                Self-employed/freelance/entrepreneur         51
#                     Working full time (paid employment)         212
#                     Youth Corper (NYSC)                          10
# 2016                Self-employed/freelance/entrepreneur         25
#                     Working full time (paid employment)          58
#                     Youth Corper (NYSC)                          77
# 2017                Self-employed/freelance/entrepreneur         10
# ...

# %%
def make_plot(the_df, field, title, figsize, rotation=None, fontsize=None):
    sns.set_style('whitegrid')
    total = len(the_df[field])*1.
    plt.figure(figsize=figsize)
    ax = sns.countplot(x = field, data = the_df, palette = 'hls' )
    plt.title(title)
    #plt.ylabel('Frequency [%]')
    plt.ylabel('Frequency')
    
    if len(ax.patches)< 8:
        # Format 250 (50%)
        for p in ax.patches:
            ax.annotate('{} ({:.1f}%)'.format(p.get_height(), 100*p.get_height()/total), (p.get_x()+0.1, p.get_height()+5))
    else:
        # Format 50%
        for p in ax.patches:

            ax.annotate('{:.1f}%'.format(100*p.get_height()/total), (p.get_x()+0.1, p.get_height()+5))
    
    ax.set_xticklabels(ax.get_xticklabels(), rotation=rotation, ha="right", fontsize=fontsize)
    plt.tight_layout()
    plt.show()

# %%
#No of people employed and year of gradution
print("\nNB: There is no info on the year a graduate started his current job")

print(gainfully_employed['Year of graduation'].value_counts())

make_plot(the_df = gainfully_employed, field='Year of graduation', title=" The number of people who are employed(E.g. in Paid employment, Nysc and Self-employed)", figsize=(8, 5))
# Out:
# NB: There is no info on the year a graduate started his current job
# 2015    273
# 2014    218
# 2013    186
# 2016    160
# 2017    107
# Name: Year of graduation, dtype: int64

# %%
plt.figure(figsize = (11, 30))

course = sns.countplot(y='Title of course studied',hue='What is your gender',data=data)

plt.savefig('course.png')

# %%
def simplify_function(the_df, field, frq):

    indx = (the_df.groupby(field)[field].count()>9).index
    bool_value =the_df.groupby(field)[field].count()
    freq = the_df.groupby(field)[field].count().values.tolist()


    indx = list(np.where(bool_value<frq, False, indx))
    freq = np.where(bool_value<frq, False, freq)

    my = (list(indx))
    freqq = list(freq)
    #print(len(freq))

    courses = [same_course for same_course in list(my) if same_course!= False ]
    frequencies = [value for value in freqq if value != False]

    courses_list = [courses[i] for i, number in enumerate(list(frequencies)) for list(courses)[i] in range(number)]
    
    d = {field: courses_list}
    mydf = pd.DataFrame(data=d)

    return mydf

# %%
mydf = simplify_function(gainfully_employed, 'Title of course studied', 9)
make_plot(the_df = mydf, field='Title of course studied', title="Which course of study has highest level of employment", figsize=(13, 8), rotation=45, fontsize=12)

# %%
#university with highest number of employee

mydf = simplify_function(gainfully_employed, 'Polytechnic/University attended', 9)
make_plot(the_df = mydf, field='Polytechnic/University attended', title="Which university has produced the highest population of working people", figsize=(14, 8), rotation=45, fontsize=12)

# %%
plt.figure(figsize = (15, 18))

jobs=sns.countplot(y='What is your job role?',hue='What is your gender',data=data)

plt.savefig('jobs.png')

# %%
#Salary of a fresh graduate
plt.figure(figsize = (15, 5))
income=sns.countplot(x='What is your current monthly income level?',hue='What is your gender',data=data)
plt.savefig('income.png')

# %%
plt.figure(figsize = (10, 5))

satisfaction = sns.countplot(y='My course of study prepared me well for employment',hue='What is your gender',data=data)

plt.savefig('satisfaction.png')

# %%
#Qualication of employability
make_plot(the_df = gainfully_employed, field='What is your highest level of education?', title="The percentage of the various degree that determine employability", figsize=(15, 5), rotation=45, fontsize=12)

# %%
gen_level=data[['What is your gender','What is your highest level of education?']]
gen_level.head()
# Out:
#    What is your gender What is your highest level of education?
# 4               Female                        Bachelor's degree
# 5                 Male                        Bachelor's degree
# 6                 Male            Higher National Diploma (HND)
# 8               Female                        Bachelor's degree
# 10                Male                        Bachelor's degree

# %%
gen_level.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1279 entries, 4 to 5217
# Data columns (total 2 columns):
# What is your gender                         1279 non-null object
# What is your highest level of education?    1279 non-null object
# dtypes: object(2)
# memory usage: 70.0+ KB

# %%
male_data=gen_level[gen_level['What is your gender'] == 'Male']['What is your highest level of education?'].value_counts()

# %%
male_data.plot.bar()

# %%
female_data=gen_level[gen_level['What is your gender'] == 'Female']['What is your highest level of education?'].value_counts()


female_data.plot.bar()

# %%
plt.figure(figsize = (10, 30))

course = sns.countplot(y='Title of course studied',hue='What is your gender',data=data)

plt.savefig('course.png')
